# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
path = '/Users/andrea/adata_laptop/'
day = 'JC315-20240401'
basename="JC315-20240401_01"

# %%
eeg = np.fromfile(path+day+"/"+basename+".eeg", dtype=np.uint16)

# %%
eeg
# Out:
# array([60841, 60990, 60158, ..., 62836, 62878, 63124], dtype=uint16)

# %%
merged_path=path+'merged/'+day

# %%
merged_path
# Out:
# '/Users/andrea/adata_laptop/merged/JC315-20240401'

# %%
plt.plot(eeg)
